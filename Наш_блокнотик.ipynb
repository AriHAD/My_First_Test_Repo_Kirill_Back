# %% [markdown]
# <a href="https://colab.research.google.com/github/AriHAD/My_First_Test_Repo_Kirill_Back/blob/main/%D0%9D%D0%B0%D1%88_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B8%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
#
# Нужно сделать:
#
# 1. Список.
# 2. Рисунок
# 3. Таблицу.
# 4. Ссылку.
#
# ![image.png](data:image/png;base64,...)
